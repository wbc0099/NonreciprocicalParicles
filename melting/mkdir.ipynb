# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from math import sqrt

# %%
len=0.9
sqrt32=sqrt(3)/2*len
devi21 = 1/2 *len

num=7
basenum=3
xlen=basenum*num
ylen=basenum*num-6

x00=6
y00=6
x0=x00
y0=y00

b=[]
a=[]

#第一列
i=0
x=x0
y=y0
z=1
while i<ylen-1:
    if z%3==0:
        z+=1
        y+=len
        continue
    b.append([x,y])
    z+=1
    y+=len
    i+=1



x0 += sqrt32
y0 -= devi21
x=x0
y=y0
i=0
z=0
k=0
while i<(xlen-2):
    if i%2==0:
       for j in range(int(ylen/2)):
            b.append([x,y])
            a.append([x,y+len])
            b.append([x,y+2*len])
            y+=3*len
    else:
        b.append([x,y])
        for j in range(int(ylen/2)-1):
            b.append([x,y+len])
            a.append([x,y+2*len])
            b.append([x,y+3*len])
            y+=3*len
        b.append([x,y+len])
    x0+=len
    y0-=devi21*((k%2)-0.5)*2
    k+=1
    x=x0
    y=y0
    i+=1

x=x0
y=y0
z=1
i=0
while i<ylen-1:
    if z%3==0:
        z+=1
        y+=len
        continue
    b.append([x,y])
    z+=1
    y+=len
    i+=1

a=np.array(a)
b=np.array(b)
plt.figure(figsize=(10,10))
plt.scatter(a[:,0],a[:,1],c='r')
plt.scatter(b[:,0],b[:,1],c='b')

# %%
print(a.shape[0])
print(b.shape[0])
print(a.shape[0]+b.shape[0])

with open('./output.txt', 'w') as f:
    np.savetxt(f,a,fmt='%.2f')
    np.savetxt(f,b,fmt='%.2f')
print('Done!')
# Out:
# 124
# 294
# 418
# Done!

# %%
xend=24
yend=24
len=28

atemp=a

for i in range(50):
    while 1:
        x=np.random.rand()*len
        y=np.random.rand()*len
        if x>x00 and x<xend and y>y00 and y<yend:
            continue
        else:
            print(x,y)
            print(atemp.shape[0])
            break
    atemp=np.append(atemp,np.array([x,y]).reshape(1,2),axis=0)
# Out:
# 19.08886417054829 24.155305012643407
# 124
# 27.90912529866194 11.213270722074482
# 125
# 13.212521893337135 3.0501294472323752
# 126
# 14.366800021115463 25.728535715632777
# 127
# 18.91351316275592 2.664565864653629
# 128
# 2.4162692481405177 12.699909242049756
# 129
# 27.036685689966134 20.766833270504932
# 130
# 11.49984724439015 0.785633801841167
# 131
# 4.8234570160396295 19.032821682798655
# 132
# 27.22529543488464 6.417600742192935
# 133
# 1.6949732321809412 3.0563950683878396
# 134
# 2.097378972933598 20.81382125550401
# 135
# 26.677849860448905 13.852531415595339
# 136
# 0.16821464096875216 17.577019710884105
# 137
# 14.703700228830515 24.181414108095044
# 138
# 4.105610845580748 22.173087089452476
# 139
# 1.353707158769946 21.788779061349697
# 140
# 0.9664806040095222 4.623303285930503
# 141
# 22.239083773420063 5.29201772101813
# 142
# 1.8990609207360674 19.785900059425515
# 143
# 23.77165922847293 0.301760274079911
# 144
# 16.005210298222707 24.877302628903173
# 145
# 23.230908095619004 4.245119436764067
# 146
# 18.856905179255282 25.340739124483406
# 147
# 26.52249966201824 13.499564436481684
# 148
# 2.2027889210279343 23.05579106226691
# 149
# 14.952149423070363 24.800162111254117
# 150
# 5.988630453502238 15.351903224107827
# 151
# 6.522179724374633 25.007255068454757
# 152
# 26.52904897484293 1.7673244605519436
# 153
# 27.887832244989372 6.553257222226429
# 154
# 21.769924056634565 3.953459258076677
# 155
# 24.610606316441068 20.258145194961138
# 156
# 6.673820988819573 27.207649214973735
# 157
# 1.6099697642597048 3.1432517536011795
# 158
# 24.927837477419185 27.048775656153946
# 159
# 12.57537154316433 2.6240128655533304
# 160
# 11.193882206915097 0.30272227256467765
# 161
# 2.674395259837643 15.211380626188644
# 162
# 3.860222608688062 14.67725544552014
# 163
# 6.4271146196562805 27.502821472534492
# 164
# 24.11469427169886 26.25992872554841
# 165
# 25.958807889902832 21.263672207163808
# 166
# 5.413829872734671 9.85933676364689
# 167
# 24.668441412819785 15.971421793316383
# 168
# 6.295680505044917 27.935074704919487
# 169
# 13.124011267824113 4.544819601079218
# 170
# 16.486014346329156 25.029870230916814
# 171
# 16.95727991942974 1.3885095466846873
# 172
# 7.293065675995528 27.525116838329343
# 173

# %%
print(atemp.shape[0])
print(b.shape[0])
print(atemp.shape[0]+b.shape[0])

with open('./output.txt', 'w') as f:
    np.savetxt(f,atemp,fmt='%.2f')
    np.savetxt(f,b,fmt='%.2f')
print('Done!')
# Out:
# 174
# 294
# 468
# Done!
